# %%
import librosa
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import librosa.display
import os

# %%
path = '/Users/sanjeevkumar/Desktop/TWR/DATA Samples/S/S = 1/'
files_s1 = []
for r,d,f in os.walk(path):
    files_s1.append(f)

# %%
path = '/Users/sanjeevkumar/Desktop/TWR/DATA Samples/S/S = 2/'
files_s2 = []
for r,d,f in os.walk(path):
    files_s2.append(f)

# %%
path = '/Users/sanjeevkumar/Desktop/TWR/DATA Samples/S/S = 3/'
files_s3 = []
for r,d,f in os.walk(path):
    files_s3.append(f)

# %%
path = '/Users/sanjeevkumar/Desktop/TWR/DATA Samples/S/S = 4/'
files_s4 = []
for r,d,f in os.walk(path):
    files_s4.append(f)

# %%
df_s1 = []
path = '/Users/sanjeevkumar/Desktop/TWR/DATA Samples/S/S = 1/'
for r,d,f in os.walk(path):
    df_s1.append(f)

# %%
for i in range(15):
    p=(r+f[i])
    df_s1.append(p)

# %%
df_s1 = pd.DataFrame(df_s1[1:],columns=['path'])
df_s1['signal'] = 1

# %%
s2 = []
path = '/Users/sanjeevkumar/Desktop/TWR/DATA Samples/S/S = 2/'
for r,d,f in os.walk(path):
    s2.append(f)

# %%
for i in range(13):
    p=(r+f[i])
    s2.append(p)

# %%
df_s2 = pd.DataFrame(s2[1:],columns=['path'])
df_s2['signal'] = 2

# %%
s3 = []
path = '/Users/sanjeevkumar/Desktop/TWR/DATA Samples/S/S = 3/'
for r,d,f in os.walk(path):
    s3.append(f)

# %%
for i in range(18):
    p=(r+f[i])
    s3.append(p)

# %%
df_s3 = pd.DataFrame(s3[1:],columns=['path'])
df_s3['signal'] = 3

# %%
s4 = []
path = '/Users/sanjeevkumar/Desktop/TWR/DATA Samples/S/S = 4/'
for r,d,f in os.walk(path):
    s4.append(f)

# %%
for i in range(18):
    p=(r+f[i])
    s4.append(p)

# %%
df_s4 = pd.DataFrame(s4[1:],columns=['path'])
df_s4['signal'] = 4

# %%
df_s_all = [df_s1,df_s2,df_s3,df_s4]
df_signal = pd.concat(df_s_all)

# %%
df_signal=df_signal.reset_index(drop=True)

# %%
pd.DataFrame(df_signal.index).duplicated().sum()
# Out:
# 0

# %%
df_signal.head(n=128)
# Out:
#                                                  path  signal
# 0   /Users/sanjeevkumar/Desktop/TWR/DATA Samples/S...       1
# 1   /Users/sanjeevkumar/Desktop/TWR/DATA Samples/S...       1
# 2   /Users/sanjeevkumar/Desktop/TWR/DATA Samples/S...       1
# 3   /Users/sanjeevkumar/Desktop/TWR/DATA Samples/S...       1
# 4   /Users/sanjeevkumar/Desktop/TWR/DATA Samples/S...       1
# ..                                                ...     ...
# 59  /Users/sanjeevkumar/Desktop/TWR/DATA Samples/S...       4
# 60  /Users/sanjeevkumar/Desktop/TWR/DATA Samples/S...       4
# 61  /Users/sanjeevkumar/Desktop/TWR/DATA Samples/S...       4
# 62  /Users/sanjeevkumar/Desktop/TWR/DATA Samples/S...       4
# 63  /Users/sanjeevkumar/Desktop/TWR/DATA Samples/S...       4
#
# [64 rows x 2 columns]

# %%
def cal_mfcc(path):
    X,sample_rate = librosa.load(path,res_type = 'kaiser_fast')
    mfcc = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0)
    feature = mfcc
    return feature

# %%
df_signal['mfcc'] = df_signal['path'].apply(cal_mfcc)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# ...

# %%
df_signal['mfcc_mean'] = df_signal['mfcc'].apply(lambda mfcc : mfcc.mean() )

# %%
def cal_zcr(path):
    X,sample_rate = librosa.load(path,res_type='kaiser_fast')
    zcr = np.mean(librosa.feature.zero_crossing_rate(X,frame_length=2048,hop_length=512,center=True))
    return zcr

# %%
df_signal['zcr'] = df_signal['path'].apply(cal_zcr)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# ...

# %%
def cal_sc(path):
        X,sample_rate = librosa.load(path,res_type='kaiser_fast')
        sc = np.mean(librosa.feature.spectral_centroid(X,sr=sample_rate,n_fft=2048,
                                                       hop_length=512,freq=None,win_length=None,window='hann',
                                                       center=True,pad_mode='reflect'))
        return sc

# %%
df_signal['sc'] = df_signal['path'].apply(cal_sc)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# ...

# %%
def cal_rms(path):
    X,sample_rate = librosa.load(path,res_type='kaiser_fast')
    rms = np.mean(librosa.feature.rms(y=X,frame_length=2048,hop_length=512,center=True,pad_mode='reflect'))
    return rms

# %%
df_signal['rms'] = df_signal['path'].apply(cal_rms)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# ...

# %%
def cal_melspectrogram(path):
    X,sample_rate = librosa.load(path,res_type='kaiser_fast')
    _melspectrogram = np.mean(librosa.feature.melspectrogram(y=X,sr=sample_rate,n_fft=2048,hop_length=512,
                                                             win_length=None,window='hann',center=True, 
                                                             pad_mode='reflect',power=2.0))
    return _melspectrogram

# %%
df_signal['melspectrogram'] = df_signal['path'].apply(cal_melspectrogram)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# /opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# ...

# %%
df_signal.head()
# Out:
#                                                 path  signal  \
# 0  /Users/sanjeevkumar/Desktop/TWR/DATA Samples/S...       1
# 1  /Users/sanjeevkumar/Desktop/TWR/DATA Samples/S...       1
# 2  /Users/sanjeevkumar/Desktop/TWR/DATA Samples/S...       1
# 3  /Users/sanjeevkumar/Desktop/TWR/DATA Samples/S...       1
# 4  /Users/sanjeevkumar/Desktop/TWR/DATA Samples/S...       1
#
#                                                 mfcc  mfcc_mean       zcr  \
# 0  [-104.80121, 216.67642, -127.55567, 48.635597,...  -0.019996  0.133246
# 1  [-103.67285, 226.84999, -134.43918, 54.319557,...  -0.045181  0.133511
# 2  [-147.70602, 214.96779, -112.369545, 54.661015...  -1.106241  0.113524
# 3  [-109.98787, 216.17279, -119.705215, 49.706768...  -0.410919  0.119944
# 4  [-123.83976, 212.2122, -110.832016, 45.81559, ...  -0.502573  0.109416
#
#             sc       rms  melspectrogram
# 0  1571.313208  0.162579        5.024878
# 1  1559.291833  0.173438        5.472262
# ...

# %%
writer = pd.ExcelWriter('signal_feature.xlsx',engine='xlsxwriter')
df_signal.to_excel(writer,sheet_name='Sheet1')
writer.save()

# %%
X = np.array(df_signal.mfcc.tolist())
y = np.array(df_signal.signal.tolist())
y = y.ravel()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.30,random_state=23)

# %%
from sklearn.neural_network import MLPClassifier
#8,4,3,
clf = MLPClassifier(hidden_layer_sizes=(15,8,5,), activation='relu', solver='adam', alpha=0.001, batch_size='auto', 
                   learning_rate='constant', max_iter=2500, verbose = False, random_state=23)

clf.fit(x_train,y_train)
print(clf.score(x_train,y_train))
print(clf.score(x_test,y_test))
# Out:
# 1.0
# 0.8

# %%
print(clf.predict(x_test[0:]))
print(y_test[0:])
# Out:
# [4 1 4 2 3 4 1 3 2 2 2 4 3 2 4 2 3 3 3 4]
# [4 1 4 2 3 4 3 1 2 2 2 4 3 2 3 2 3 3 1 4]
